# %%
import pandas as pd
from tqdm import tqdm
import os
import re
from math import sqrt
import matplotlib.pyplot as plt

from statsmodels.tsa.api import Holt, ExponentialSmoothing
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.metrics import mean_squared_error

# %%
def load_csv_file(filename):
    try:
        if not os.path.exists(filename):
            print(f"The file: {filename} doesn't exist")
        else:
            print("Found File")
            return pd.concat([chunk for chunk in tqdm(pd.read_csv(filename, chunksize=1000), desc=f'Loading {filename}')])
    except:
        print("Didn't Work! :(")

# %% [markdown]
# # Spotify + Hot 100

# %% [markdown]
# ## Poularity & Chart Position

# %% [markdown]
# https://www.kaggle.com/datasets/paradisejoy/top-hits-spotify-from-20002019
#
# https://github.com/HipsterVizNinja/random-data/blob/main/Music/hot-100/Hot%20100.csv

# %% [markdown]
# > # Notes

# %% [markdown]
# Chart position: create a feature that represents the average chart position for each song in the Billboard Hot 100 dataset.
#
# Peak position: create a feature that represents the peak position for each song in the Billboard Hot 100 dataset.
#
# Times on chart: create a feature that represents the number of times each song appeared on the Billboard Hot 100 chart.
#
# Consecutive weeks: create a feature that represents the number of consecutive weeks each song appeared on the Billboard Hot 100 chart.
#
# Popularity: use the "popularity" feature from the Spotify dataset to represent the overall popularity of each song.
#
# Genre: use the "genre" feature from the Spotify dataset to represent the genre of each song.
#
# Danceability: use the "danceability" feature from the Spotify dataset to represent how suitable each song is for dancing.
#
# Energy: use the "energy" feature from the Spotify dataset to represent the overall energy of each song.
#
# Popularity and chart position: create a new feature that represents the product of the popularity and the average chart position for each song. This feature could capture the relationship between popularity and chart position.
#
# Popularity and times on chart: create a new feature that represents the product of the popularity and the number of times each song appeared on the Billboard Hot 100 chart. This feature could capture the relationship between popularity and how frequently the song has been on the chart.
#
# Popularity and peak position: create a new feature that represents the product of the popularity and the peak position for each song. This feature could capture the relationship between popularity and the highest position the song has achieved on the chart.
#
# Popularity and average of positions: create a new feature that represents the product of the popularity and the average of all the positions the song achieved on the chart. This feature could capture the relationship between popularity and the average performance of the song on the chart.

# %%
df = load_csv_file('songs_normalize.csv')
# Out:
# Found File
# Loading songs_normalize.csv: 2it [00:00, 149.77it/s]

# %%
df.shape
# Out:
# (2000, 18)

# %%
df.head()
# Out:
#            artist                    song  duration_ms  explicit  year  \
# 0  Britney Spears  Oops!...I Did It Again       211160     False  2000
# 1       blink-182    All The Small Things       167066     False  1999
# 2      Faith Hill                 Breathe       250546     False  1999
# 3        Bon Jovi            It's My Life       224493     False  2000
# 4          *NSYNC             Bye Bye Bye       200560     False  2000
#
#    popularity  danceability  energy  key  loudness  mode  speechiness  \
# 0          77         0.751   0.834    1    -5.444     0       0.0437
# 1          79         0.434   0.897    0    -4.918     1       0.0488
# 2          66         0.529   0.496    7    -9.007     1       0.0290
# 3          78         0.551   0.913    0    -4.063     0       0.0466
# 4          65         0.614   0.928    8    -4.806     0       0.0516
#
#    acousticness  instrumentalness  liveness  valence    tempo         genre
# 0        0.3000          0.000018    0.3550    0.894   95.053           pop
# 1        0.0103          0.000000    0.6120    0.684  148.726     rock, pop
# 2        0.1730          0.000000    0.2510    0.278  136.859  pop, country
# 3        0.0263          0.000013    0.3470    0.544  119.992   rock, metal
# 4        0.0408          0.001040    0.0845    0.879  172.656           pop

# %%
# Popularity Range

# %%
df['popularity'].min()
# Out:
# 0

# %%
df['popularity'].max()
# Out:
# 89

# %%
hot_100_df = load_csv_file("hot_100.csv")
# Out:
# Found File
# Loading hot_100.csv: 337it [00:00, 456.65it/s]

# %%
hot_100_df.head(1)
# Out:
#    chart_position  chart_date       song           performer  \
# 0              84  1990-05-05  "B" Girls  Young And Restless
#
#                        song_id  instance  time_on_chart  consecutive_weeks  \
# 0  "B" GirlsYoung And Restless       1.0              1                NaN
#
#    previous_week  peak_position  worst_position chart_debut  \
# 0            NaN             84              84  1990-05-05
#
#                                            chart_url
# 0  https://www.billboard.com/charts/hot-100/1990-...

# %%
# set datetime data type and sort
hot_100_df['chart_date']=pd.to_datetime(hot_100_df['chart_date'])

# %%
hot_100_df.head(1)
# Out:
#    chart_position chart_date       song           performer  \
# 0              84 1990-05-05  "B" Girls  Young And Restless
#
#                        song_id  instance  time_on_chart  consecutive_weeks  \
# 0  "B" GirlsYoung And Restless       1.0              1                NaN
#
#    previous_week  peak_position  worst_position chart_debut  \
# 0            NaN             84              84  1990-05-05
#
#                                            chart_url
# 0  https://www.billboard.com/charts/hot-100/1990-...

# %%
# set 'date' column as index and sorted
hot_100_df = hot_100_df.set_index("chart_date").sort_index()

# %%
hot_100_df["performer"]
# Out:
#             chart_position                          song  \
# chart_date
# 1958-08-02              69                            Op
# 1958-08-02              33                    The Freeze
# 1958-08-02              21  Guess Things Happen That Way
#
#                                     performer  \
# chart_date
# 1958-08-02                     The Honeycones
# 1958-08-02                       Tony And Joe
# 1958-08-02  Johnny Cash And The Tennessee Two
#
#                                                       song_id  instance  \
# chart_date
# 1958-08-02                                   OpThe Honeycones       1.0
# 1958-08-02                             The FreezeTony And Joe       1.0
# 1958-08-02  Guess Things Happen That WayJohnny Cash And Th...       1.0
#
#             time_on_chart  consecutive_weeks  previous_week  peak_position  \
# chart_date
# 1958-08-02              1                NaN            NaN             69
# 1958-08-02              1                NaN            NaN             33
# 1958-08-02              1                NaN            NaN             21
#
#             worst_position chart_debut  \
# chart_date
# 1958-08-02              69  1958-08-02
# 1958-08-02              33  1958-08-02
# 1958-08-02              21  1958-08-02
#
#                                                     chart_url
# chart_date
# 1958-08-02  https://www.billboard.com/charts/hot-100/1958-...
# 1958-08-02  https://www.billboard.com/charts/hot-100/1958-...
# 1958-08-02  https://www.billboard.com/charts/hot-100/1958-...

# %%
hot_100_df[(hot_100_df['performer'].str.contains('santana',case=False))].loc['2000-01-01':'2000-12-31']
# Out:
#             chart_position         song                          performer  \
# chart_date
# 2000-01-01               1       Smooth       Santana Featuring Rob Thomas
# 2000-01-08               1       Smooth       Santana Featuring Rob Thomas
# 2000-01-15               2       Smooth       Santana Featuring Rob Thomas
# 2000-01-22               3       Smooth       Santana Featuring Rob Thomas
# 2000-01-29               3       Smooth       Santana Featuring Rob Thomas
# ...                    ...          ...                                ...
# 2000-08-05              47  Maria Maria  Santana Featuring The Product G&B
# 2000-08-12              36       Smooth       Santana Featuring Rob Thomas
# 2000-08-19              43       Smooth       Santana Featuring Rob Thomas
# 2000-08-26              46       Smooth       Santana Featuring Rob Thomas
# 2000-09-02              48       Smooth       Santana Featuring Rob Thomas
#
#                                                  song_id  instance  \
# chart_date
# 2000-01-01            SmoothSantana Featuring Rob Thomas       1.0
# 2000-01-08            SmoothSantana Featuring Rob Thomas       1.0
# 2000-01-15            SmoothSantana Featuring Rob Thomas       1.0
# 2000-01-22            SmoothSantana Featuring Rob Thomas       1.0
# 2000-01-29            SmoothSantana Featuring Rob Thomas       1.0
# ...                                                  ...       ...
# 2000-08-05  Maria MariaSantana Featuring The Product G&B       1.0
# 2000-08-12            SmoothSantana Featuring Rob Thomas       1.0
# 2000-08-19            SmoothSantana Featuring Rob Thomas       1.0
# 2000-08-26            SmoothSantana Featuring Rob Thomas       1.0
# 2000-09-02            SmoothSantana Featuring Rob Thomas       1.0
#
#             time_on_chart  consecutive_weeks  previous_week  peak_position  \
# chart_date
# 2000-01-01             23               22.0            1.0              1
# 2000-01-08             24               23.0            1.0              1
# 2000-01-15             25               24.0            1.0              1
# 2000-01-22             26               25.0            2.0              1
# 2000-01-29             27               26.0            3.0              1
# ...                   ...                ...            ...            ...
# 2000-08-05             26               25.0           48.0              1
# 2000-08-12             55               54.0           39.0              1
# 2000-08-19             56               55.0           36.0              1
# 2000-08-26             57               56.0           43.0              1
# 2000-09-02             58               57.0           46.0              1
#
#             worst_position chart_debut  \
# chart_date
# 2000-01-01              78  1999-07-31
# 2000-01-08              78  1999-07-31
# 2000-01-15              78  1999-07-31
# 2000-01-22              78  1999-07-31
# 2000-01-29              78  1999-07-31
# ...                    ...         ...
# 2000-08-05              48  2000-02-12
# 2000-08-12              78  1999-07-31
# 2000-08-19              78  1999-07-31
# 2000-08-26              78  1999-07-31
# 2000-09-02              78  1999-07-31
#
#                                                     chart_url
# chart_date
# 2000-01-01  https://www.billboard.com/charts/hot-100/2000-...
# 2000-01-08  https://www.billboard.com/charts/hot-100/2000-...
# 2000-01-15  https://www.billboard.com/charts/hot-100/2000-...
# 2000-01-22  https://www.billboard.com/charts/hot-100/2000-...
# 2000-01-29  https://www.billboard.com/charts/hot-100/2000-...
# ...                                                       ...
# 2000-08-05  https://www.billboard.com/charts/hot-100/2000-...
# 2000-08-12  https://www.billboard.com/charts/hot-100/2000-...
# 2000-08-19  https://www.billboard.com/charts/hot-100/2000-...
# 2000-08-26  https://www.billboard.com/charts/hot-100/2000-...
# 2000-09-02  https://www.billboard.com/charts/hot-100/2000-...
#
# [62 rows x 12 columns]

# %%
hot_100_df.loc['2000-01-08':'2000-01-10'].sort_values('chart_position')
# Out:
#             chart_position                      song  \
# chart_date
# 2000-01-08               1                    Smooth
# 2000-01-08               2               Back At One
# 2000-01-08               3  I Wanna Love You Forever
# 2000-01-08               4      My Love Is Your Love
# 2000-01-08               5                  Hot Boyz
# ...                    ...                       ...
# 2000-01-08              96          Larger Than Life
# 2000-01-08              97     The Best Man I Can Be
# 2000-01-08              98                 L.A. Song
# 2000-01-08              99               Re-arranged
# 2000-01-08             100         The Quittin' Kind
#
#                                                     performer  \
# chart_date
# 2000-01-08                       Santana Featuring Rob Thomas
# 2000-01-08                                     Brian McKnight
# 2000-01-08                                    Jessica Simpson
# 2000-01-08                                    Whitney Houston
# 2000-01-08  Missy "Misdemeanor" Elliott Featuring NAS, EVE...
# ...                                                       ...
# 2000-01-08                                    Backstreet Boys
# 2000-01-08                       Ginuwine, R.L., Tyrese, Case
# 2000-01-08                                          Beth Hart
# 2000-01-08                                        Limp Bizkit
# 2000-01-08                                         Joe Diffie
#
#                                                       song_id  instance  \
# chart_date
# 2000-01-08                 SmoothSantana Featuring Rob Thomas       1.0
# 2000-01-08                          Back At OneBrian McKnight       1.0
# 2000-01-08            I Wanna Love You ForeverJessica Simpson       1.0
# 2000-01-08                My Love Is Your LoveWhitney Houston       1.0
# 2000-01-08  Hot BoyzMissy "Misdemeanor" Elliott Featuring ...       1.0
# ...                                                       ...       ...
# 2000-01-08                    Larger Than LifeBackstreet Boys       1.0
# 2000-01-08  The Best Man I Can BeGinuwine, R.L., Tyrese, Case       1.0
# 2000-01-08                                 L.A. SongBeth Hart       1.0
# 2000-01-08                             Re-arrangedLimp Bizkit       1.0
# 2000-01-08                        The Quittin' KindJoe Diffie       1.0
#
#             time_on_chart  consecutive_weeks  previous_week  peak_position  \
# chart_date
# 2000-01-08             24               23.0            1.0              1
# 2000-01-08             20               19.0            2.0              2
# 2000-01-08             13               12.0            3.0              3
# 2000-01-08             19               18.0            4.0              4
# 2000-01-08              7                6.0            7.0              5
# ...                   ...                ...            ...            ...
# 2000-01-08             17               16.0           87.0             25
# 2000-01-08              1                NaN            NaN             97
# 2000-01-08              7                6.0           96.0             96
# 2000-01-08              6                5.0           95.0             90
# 2000-01-08              2                1.0           98.0             98
#
#             worst_position chart_debut  \
# chart_date
# 2000-01-08              78  1999-07-31
# 2000-01-08              75  1999-08-28
# 2000-01-08              69  1999-10-16
# 2000-01-08              81  1999-09-04
# 2000-01-08              36  1999-11-27
# ...                    ...         ...
# 2000-01-08              96  1999-09-18
# 2000-01-08              97  2000-01-08
# 2000-01-08             100  1999-11-27
# 2000-01-08              99  1999-12-04
# 2000-01-08             100  2000-01-01
#
#                                                     chart_url
# chart_date
# 2000-01-08  https://www.billboard.com/charts/hot-100/2000-...
# 2000-01-08  https://www.billboard.com/charts/hot-100/2000-...
# 2000-01-08  https://www.billboard.com/charts/hot-100/2000-...
# 2000-01-08  https://www.billboard.com/charts/hot-100/2000-...
# 2000-01-08  https://www.billboard.com/charts/hot-100/2000-...
# ...                                                       ...
# 2000-01-08  https://www.billboard.com/charts/hot-100/2000-...
# 2000-01-08  https://www.billboard.com/charts/hot-100/2000-...
# 2000-01-08  https://www.billboard.com/charts/hot-100/2000-...
# 2000-01-08  https://www.billboard.com/charts/hot-100/2000-...
# 2000-01-08  https://www.billboard.com/charts/hot-100/2000-...
#
# [100 rows x 12 columns]

# %% [markdown]
# # XGBoost

# %%
from xgboost import XGBClassifier
from sklearn.metrics import make_scorer, accuracy_score, roc_auc_score

# %%
xgb_model = XGBClassifier(objective = "binary:logistic", n_estimators = 10, seed = 123)
xgb_model.fit(X_train, y_train)
xgb_predict = xgb_model.predict(X_validate)
xgb_accuracy = accuracy_score(y_validate, xgb_predict)
print("Accuracy: " + str(xgb_accuracy))
